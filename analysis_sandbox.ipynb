# %%
import pandas

# %%
people_df = pandas.read_csv('people.csv', header=0) #index_col=0)

# %%
people_df
# Out:
#   person name or identifier           event career stage self-defined field  \
# 0             Rita Busuttil  Melbourne 2015      postdoc    cancer genomics
# 1            Kate Giljohann  Melbourne 2015          phd            ecology
# 2            Michael Strack  Melbourne 2015          phd  microbial ecology
# 3                       NaN             NaN          NaN                NaN
#
#                 research_group operating system programming_languages  \
# 0  oncology and carcinogenesis              NaN                   NaN
# 1                      ecology          windows                     R
# 2                      ecology          windows                     R
# 3                          NaN              NaN                   NaN
#
#      general_datasci_tools discipline_datasci_tools  \
# 0           GraphPad Prism      Partek, IGV, ImageJ
# 1  Microsoft Excel, ArcGIS                      NaN
# 2          Microsoft Excel               GeneMapper
# 3                      NaN                      NaN
#
#                                        support_tools
# 0                          Word, Dropbox, PowerPoint
# 1  RStudio, Word, Dropbox, PowerPoint, Scribus, M...
# 2  Word, OneDrive, PowerPoint, Prezi, Mendeley, G...
# 3                                                NaN

# %%
print(people_df['person name or identifier'])
# Out:
# 0     Rita Busuttil
# 1    Kate Giljohann
# 2    Michael Strack
# 3               NaN
# Name: person name or identifier, dtype: object

# %%
print(people_df['general_datasci_tools'])
# Out:
# 0             GraphPad Prism
# 1    Microsoft Excel, ArcGIS
# 2            Microsoft Excel
# 3                        NaN
# Name: general_datasci_tools, dtype: object

# %%
people_df['support_tools'][0].split(',')
# Out:
# ['Word', ' Dropbox', ' PowerPoint']

# %%
res_groups_df = pandas.read_csv('anzsrc_research_groups.csv', header=0)

# %%
res_groups_df
# Out:
#                                         research_group  \
# 0                                     pure mathematics
# 1                                  applied mathematics
# 2              numerical and computational mathematics
# 3                                           statistics
# 4                                 mathematical physics
# 5                          other mathematical sciences
# 6                      astronomical and space sciences
# 7    atomic, molecular, nuclear, particle and plasm...
# 8                                    classical physics
# 9                             condensed matter physics
# 10                                     optical physics
# 11                                     quantum physics
# 12                             other physical sciences
# 13                                 analytical chemisty
# 14                                 inorganic chemistry
# 15                             macromolecular chemisty
# 16                medicinal and biomolecular chemistry
# 17                                   organic chemistry
# 18               physical chemistry (incl. structural)
# 19             theoretical and computational chemistry
# 20                             other chemical sciecnes
# 21                                atmospheric sciences
# 22                                        geochemistry
# 23                                             geology
# 24                                          geophysics
# 25                                        oceanography
# 26     physical geography and environmental geoscience
# 27                                other earth sciences
# 28                             ecological applications
# 29                environmental science and management
# ..                                                 ...
# 127                                        social work
# 128                                          sociology
# 129                     other studies in human society
# 130                                         psychology
# 131                                 cognitive sciences
# 132            other psychology and cognitive sciences
# 133                                                law
# 134                        other law and legal studies
# 135                           art theory and criticism
# 136                 film, television and digital media
# 137                journalism and professional writing
# 138               performing arts and creative writing
# 139                             visual arts and crafts
# 140         other studies in creative arts and writing
# 141                    communication and media studies
# 142                                   cultural studies
# 143                                   language studies
# 144                                        linguistics
# 145                                   literary studies
# 146          other language, communication and culture
# 147                                        archaeology
# 148                     curatorial and related studies
# 149                                 historical studies
# 150                      other history and archaeology
# 151                                     applied ethics
# 152          history and philosophy of specific fields
# 153                                         philosophy
# 154                     religion and religious studies
# 155             other philosophy and religious studies
# 156                                                NaN
#
#                         research_division people
# 0                   mathematical sciences    NaN
# 1                   mathematical sciences    NaN
# 2                   mathematical sciences    NaN
# 3                   mathematical sciences    NaN
# 4                   mathematical sciences    NaN
# 5                   mathematical sciences    NaN
# 6                       physical sciences    NaN
# 7                       physical sciences    NaN
# 8                       physical sciences    NaN
# 9                       physical sciences    NaN
# 10                      physical sciences    NaN
# 11                      physical sciences    NaN
# 12                      chemical sciences    NaN
# 13                      chemical sciences    NaN
# 14                      chemical sciences    NaN
# 15                      chemical sciences    NaN
# 16                      chemical sciences    NaN
# 17                      chemical sciences    NaN
# 18                      chemical sciences    NaN
# 19                      chemical sciences    NaN
# 20                      chemical sciences    NaN
# 21                         earth sciences    NaN
# 22                         earth sciences    NaN
# 23                         earth sciences    NaN
# 24                         earth sciences    NaN
# 25                         earth sciences    NaN
# 26                         earth sciences    NaN
# 27                         earth sciences    NaN
# 28                 environmental sciences    NaN
# 29                 environmental sciences    NaN
# ..                                    ...    ...
# 127              studies in human society    NaN
# 128              studies in human society    NaN
# 129              studies in human society    NaN
# 130     psychology and cognitive sciences    NaN
# 131     psychology and cognitive sciences    NaN
# 132     psychology and cognitive sciences    NaN
# 133                 law and legal studies    NaN
# 134                 law and legal studies    NaN
# 135  studies in creative arts and writing    NaN
# 136  studies in creative arts and writing    NaN
# 137  studies in creative arts and writing    NaN
# 138  studies in creative arts and writing    NaN
# 139  studies in creative arts and writing    NaN
# 140  studies in creative arts and writing    NaN
# 141   language, communication and culture    NaN
# 142   language, communication and culture    NaN
# 143   language, communication and culture    NaN
# 144   language, communication and culture    NaN
# 145   language, communication and culture    NaN
# 146   language, communication and culture    NaN
# 147               history and archaeology    NaN
# 148               history and archaeology    NaN
# 149               history and archaeology    NaN
# 150               history and archaeology    NaN
# 151      philosophy and religious studies    NaN
# 152      philosophy and religious studies    NaN
# 153      philosophy and religious studies    NaN
# 154      philosophy and religious studies    NaN
# 155      philosophy and religious studies    NaN
# 156                                   NaN    NaN
#
# [157 rows x 3 columns]

# %%
small_res_groups_df = res_groups_df[['research_group','research_division']].set_index('research_group')
combo = people_df.join(small_res_groups_df, on=['research_group'])

# %%
combo
# Out:
#   person name or identifier           event career stage self-defined field  \
# 0             Rita Busuttil  Melbourne 2015      postdoc    cancer genomics
# 1            Kate Giljohann  Melbourne 2015          phd            ecology
# 2            Michael Strack  Melbourne 2015          phd  microbial ecology
# 3                       NaN             NaN          NaN                NaN
#
#                 research_group operating system programming_languages  \
# 0  oncology and carcinogenesis              NaN                   NaN
# 1                      ecology          windows                     R
# 2                      ecology          windows                     R
# 3                          NaN              NaN                   NaN
#
#      general_datasci_tools discipline_datasci_tools  \
# 0           GraphPad Prism      Partek, IGV, ImageJ
# 1  Microsoft Excel, ArcGIS                      NaN
# 2          Microsoft Excel               GeneMapper
# 3                      NaN                      NaN
#
#                                        support_tools  \
# 0                          Word, Dropbox, PowerPoint
# 1  RStudio, Word, Dropbox, PowerPoint, Scribus, M...
# 2  Word, OneDrive, PowerPoint, Prezi, Mendeley, G...
# 3                                                NaN
#
#              research_division
# 0  medical and health sciences
# 1          biological sciences
# 2          biological sciences
# 3                          NaN

# %%
row = combo.iloc[1].copy()

# %%
tools_list = row['support_tools'].split(',')

# %%
row
# Out:
# person name or identifier                                       Kate Giljohann
# event                                                           Melbourne 2015
# career stage                                                               phd
# self-defined field                                                     ecology
# research_group                                                           hello
# operating system                                                       windows
# programming_languages                                                        R
# general_datasci_tools                                  Microsoft Excel, ArcGIS
# discipline_datasci_tools                                                   NaN
# support_tools                RStudio, Word, Dropbox, PowerPoint, Scribus, M...
# research_division                                          biological sciences
# Name: 1, dtype: object

# %%
row[['person name or identifier', 'research_group', 'research_division', 'support_tools']]
# Out:
# person name or identifier                                       Kate Giljohann
# research_group                                                         goodbye
# research_division                                          biological sciences
# support_tools                RStudio, Word, Dropbox, PowerPoint, Scribus, M...
# Name: 1, dtype: object

# %%
test = pandas.DataFrame()

# %%
new_row = row[['person name or identifier', 'research_group', 'research_division', 'support_tools']].copy()

# %%
new_row['support_tools'] = 'yahoo'

# %%
test = test.append(new_row)

# %%
test
# Out:
#   person name or identifier    research_division research_group support_tools
# 1            Kate Giljohann  biological sciences        goodbye         yahoo

# %%
test = test.append(new_row)

# %%
test
# Out:
#   person name or identifier    research_division research_group support_tools
# 1            Kate Giljohann  biological sciences        goodbye         yahoo
# 1            Kate Giljohann  biological sciences        goodbye         yahoo

# %%
pandas.notnull(row['general_datasci_tools'])
# Out:
# True

# %%
row['discipline_datasci_tools']
# Out:
# nan
